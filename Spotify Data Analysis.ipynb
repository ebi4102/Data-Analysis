# %% [markdown]
# ###  This project involves the analysis of data related to top hip-hop artists and their tracks.  The dataset contains information such as track names, artist names, popularity scores, and track durations.  Using Python and various data analysis libraries such as pandas, numpy, matplotlib, and seaborn,  we explore different aspects of the data, including average popularity scores, track durations, correlations, and distributions. The analysis includes calculations, visualizations, and data manipulation techniques to gain insights into the dataset.

# %% [markdown]
# ### Import numpy and pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import visualization libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read in the csv file as a dataframe called df

# %%
df=pd.read_csv('top_hiphop_artists_tracks.csv')
df.head()
# Out:
#   Artist                               Track Name  Popularity  Duration (ms)  \
# 0  Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92         319191
# 1  Drake                                One Dance          91         173986
# 2  Drake                       IDGAF (feat. Yeat)          90         260111
# 3  Drake     First Person Shooter (feat. J. Cole)          88         247444
# 4  Drake            Jimmy Cooks (feat. 21 Savage)          88         218364
#
#                  Track ID
# 0  1yeB8MUNeLo9Ek1UEpsyz6
# 1  1zi7xx7UVEFkmKfv06H8x0
# 2  2YSzYUF3jWqb9YP9VXmpjE
# 3  7aqfrAY2p9BUSiupwk3svU
# 4  3F5CgOj3wFlRv51JsHbxhe

# %% [markdown]
# ### 1.Calculate the average popularity score of the tracks.

# %%
df['Popularity'].mean()
# Out:
# 75.73636363636363

# %% [markdown]
# ### 2.Find the maximum and minimum duration of the tracks.

# %%
df['Duration (ms)'].agg(['min', 'max'])
# Out:
# min     81666
# max    501648
# Name: Duration (ms), dtype: int64

# %% [markdown]
# ### 3.Calculate the correlation between popularity scores and track durations.

# %%
df.corr(numeric_only=True)
# Out:
#                Popularity  Duration (ms)
# Popularity       1.000000       0.040745
# Duration (ms)    0.040745       1.000000

# %% [markdown]
# ### 4.Determine the median popularity score of the tracks.

# %%
df['Popularity'].median()
# Out:
# 77.0

# %% [markdown]
# ### 5.Load the dataset and display the first few rows to understand its structure.

# %%
df.head()
# Out:
#   Artist                               Track Name  Popularity  Duration (ms)  \
# 0  Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92         319191
# 1  Drake                                One Dance          91         173986
# 2  Drake                       IDGAF (feat. Yeat)          90         260111
# 3  Drake     First Person Shooter (feat. J. Cole)          88         247444
# 4  Drake            Jimmy Cooks (feat. 21 Savage)          88         218364
#
#                  Track ID
# 0  1yeB8MUNeLo9Ek1UEpsyz6
# 1  1zi7xx7UVEFkmKfv06H8x0
# 2  2YSzYUF3jWqb9YP9VXmpjE
# 3  7aqfrAY2p9BUSiupwk3svU
# 4  3F5CgOj3wFlRv51JsHbxhe

# %% [markdown]
# ### 6.Check for missing values in the dataset and handle them appropriately.

# %%
df.isna().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %% [markdown]
# ### 7.Group the data by artist and calculate the average popularity score for each artist.

# %%
df.groupby('Artist')['Popularity'].mean()
# Out:
# Artist
# *NSYNC                    67.000000
# 2 Chainz                  72.000000
# 21 Savage                 84.181818
# A Boogie Wit da Hoodie    80.000000
# A$AP Ferg                 69.000000
#                             ...
# Young Nudy                67.000000
# Young Thug                73.750000
# benny blanco              72.000000
# cassö                     92.000000
# ¥$                        86.090909
# Name: Popularity, Length: 115, dtype: float64

# %% [markdown]
# ### 8.Filter the dataset to only include tracks with a popularity score above a certain threshold.

# %%
popularity_threshold = 70 
filtered_df = df[df['Popularity'] > popularity_threshold]
print(filtered_df)
# Out:
#              Artist                               Track Name  Popularity  \
# 0             Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92
# 1             Drake                                One Dance          91
# 2             Drake                       IDGAF (feat. Yeat)          90
# 3             Drake     First Person Shooter (feat. J. Cole)          88
# 4             Drake            Jimmy Cooks (feat. 21 Savage)          88
# ..              ...                                      ...         ...
# 425          Offset                             ON THE RIVER          75
# 426          Offset             WORTH IT (feat. Don Toliver)          72
# 427       21 Savage   Ghostface Killers (feat. Travis Scott)          73
# 428          Offset                 BROAD DAY (feat. Future)          72
# 430  French Montana                            Unforgettable          87
#
#      Duration (ms)                Track ID
# 0           319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %% [markdown]
# ### 9.Sort the dataset based on track duration in descending order.

# %%
df.sort_values(by='Duration (ms)',ascending=False)
# Out:
#                 Artist                                         Track Name  \
# 419          DJ Khaled  GOD DID (feat. Rick Ross, Lil Wayne, Jay-Z, Jo...
# 88              Eminem                                               Stan
# 91      Kendrick Lamar                                        Money Trees
# 173       Travis Scott                          SKITZO (feat. Young Thug)
# 62               Drake                                            Forever
# ..                 ...                                                ...
# 357          Ice Spice                                  Munch (Feelin’ U)
# 181        Central Cee                                               Doja
# 425             Offset                                       ON THE RIVER
# 288      Playboi Carti                                           New Tank
# 362  Justin Timberlake                                     BroZone's Back
#
#      Popularity  Duration (ms)                Track ID
# ...

# %% [markdown]
# ### 10.Plot a line graph showing the trend of popularity scores over time (assuming there is a time-related column in the dataset).

# %%
df['Popularity'].plot()
plt.title('Popularity')
# Out:
# Text(0.5, 1.0, 'Popularity')

# %% [markdown]
# ### 11.Create a bar chart to visualize the top N artists based on their average popularity scores.

# %%
Average_Popularity = df.groupby('Artist')['Popularity'].mean()
sorted_artists = average_popularity.sort_values(ascending=False)
top_n_artists = sorted_artists.head()
plt.figure(figsize=(10, 6))
top_n_artists.plot(kind='bar', color='brown')
plt.title('Top Hip-Hop Artists by Average Popularity Score'.format(top_n))
# Out:
# Text(0.5, 1.0, 'Top Hip-Hop Artists by Average Popularity Score')

# %% [markdown]
# ### 12.Use subplots to compare the distributions of popularity scores and track durations side by side.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot histogram for popularity scores
axes[0].hist(df['Popularity'], bins=20, color='skyblue',edgecolor='black')
axes[0].set_title('Distribution of Popularity Scores')
axes[0].set_xlabel('Popularity Score')
axes[0].set_ylabel('Frequency')

# Plot histogram for track durations
axes[1].hist(df['Duration (ms)'],bins=20,  color='lightgreen',edgecolor='black')
axes[1].set_title('Distribution of Track Durations')
axes[1].set_xlabel('Duration (ms)')
axes[1].set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### 13.Visualize the distribution of popularity scores using a histogram.

# %%
sns.histplot(df['Popularity'])
# Out:
# <Axes: xlabel='Popularity', ylabel='Count'>

# %% [markdown]
# ### 14. Create a boxplot to compare the popularity scores of tracks across different artists.

# %%
plt.figure(figsize=(30,15))
sns.boxplot(x=df['Artist'],y=df['Popularity'])
# Out:
# <Axes: xlabel='Artist', ylabel='Popularity'>

# %% [markdown]
# ### 15.Use a scatter plot to explore the relationship between track duration and popularity.

# %%
plt.scatter(x=df['Duration (ms)'], y=df['Popularity'], color='skyblue')
plt.title('Relationship between Track Duration and Popularity')
# Out:
# Text(0.5, 1.0, 'Relationship between Track Duration and Popularity')

# %% [markdown]
# ### 16.Create a violin plot to compare the distribution of track durations for different artists.

# %%
plt.figure(figsize=(30, 30))
sns.violinplot(x='Artist', y='Duration (ms)', data=df, palette='pastel')
plt.title('Distribution of Track Durations for Different Artists')
plt.xlabel('Artist')
plt.ylabel('Duration (ms)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
